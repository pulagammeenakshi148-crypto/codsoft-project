# %% [markdown]
# <a href="https://colab.research.google.com/github/pulagammeenakshi148-crypto/codsoft-project/blob/main/Untitled15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
import io
import pandas as pd
from google.colab import files
uploaded = files.upload()
iris = pd.read_csv((io.BytesIO(uploaded['IRIS.csv'])))
# Out:
#      <input type="file" id="files-e75eaf3b-67d3-4828-bfe0-d8f80342c865" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e75eaf3b-67d3-4828-bfe0-d8f80342c865">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
iris.head(10)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
# 5           5.4          3.9           1.7          0.4  Iris-setosa
# 6           4.6          3.4           1.4          0.3  Iris-setosa
# 7           5.0          3.4           1.5          0.2  Iris-setosa
# 8           4.4          2.9           1.4          0.2  Iris-setosa
# 9           4.9          3.1           1.5          0.1  Iris-setosa

# %%
iris.shape
# Out:
# (150, 5)

# %%
iris.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
from sklearn.preprocessing import LabelEncoder
from pandas.core.dtypes.common import is_numeric_dtype
le = LabelEncoder()

# %%
for i in iris.columns:
  if is_numeric_dtype(iris[i]):
    continue
else:
      iris[i] = le.fit_transform(iris[i])

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    int64
# dtypes: float64(4), int64(1)
# memory usage: 6.0 KB

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(x='species', data=iris, palette="Set2")
plt.show()
# Out:
# /tmp/ipykernel_3064/3349311583.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='species', data=iris, palette="Set2")

# %%
sns.histplot(data = iris,x=iris.sepal_length,color='green')
# Out:
# <Axes: xlabel='sepal_length', ylabel='Count'>

# %%
sns.histplot(data = iris,x=iris.sepal_width,color='blue')
# Out:
# <Axes: xlabel='sepal_width', ylabel='Count'>

# %%
sns.histplot(data = iris,x=iris.petal_length,color='brown')
# Out:
# <Axes: xlabel='petal_length', ylabel='Count'>

# %%
sns.histplot(data = iris,x=iris.petal_width,color='orange')
# Out:
# <Axes: xlabel='petal_width', ylabel='Count'>

# %%
corr=iris.corr()
sns.heatmap(corr,annot=True)
# Out:
# <Axes: >

# %%
from sklearn.model_selection import train_test_split

# %%
iris.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
x= iris.drop(['species'],axis=1)
y=iris.species

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3)

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
print("Score for Train data",model.score(x_train, y_train))
print("Score for Test data",model.score(x_test, y_test))
# Out:
# Score for Train data 0.9714285714285714
# Score for Test data 1.0

# %%
from sklearn.ensemble import RandomForestClassifier
model2 = RandomForestClassifier(n_estimators = 300 , random_state=100)
model2.fit(x_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=300, random_state=100)

# %%
print("Score for Train data",model2.score(x_train, y_train))
print("Score for Test data",model2.score(x_test, y_test))
# Out:
# Score for Train data 1.0
# Score for Test data 1.0

# %%
from sklearn.neighbors import KNeighborsClassifier
model3 = KNeighborsClassifier()
model3.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
print("Score for Train data",model3.score(x_train, y_train))
print("Score for Test data",model3.score(x_test, y_test))
# Out:
# Score for Train data 0.9523809523809523
# Score for Test data 1.0

# %%
iris.head(5)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width  species
# 0           5.1          3.5           1.4          0.2        0
# 1           4.9          3.0           1.4          0.2        0
# 2           4.7          3.2           1.3          0.2        0
# 3           4.6          3.1           1.5          0.2        0
# 4           5.0          3.6           1.4          0.2        0

# %%
data = {'sepal_length': [5.2],
        'sepal_width': [3.6],
        'petal_length': [1.4],
        'petal_width': [0.2]}
trail = pd.DataFrame(data)

# %%
result = model.predict(trail)
print("Result Species:", result[0])
# Out:
# Result Species: 0
